# %% [markdown]
# # Other Local Statistics
# ## Local Geary's-c
# ### Definition
# ![image.png](attachment:732015e4-488a-4da4-bb09-2e84d5ecf9c5.png)

# %% [markdown]
# ### Moments of Local Geary C
# ![image.png](attachment:a83eaa3c-1429-4870-8bc2-50cc12134427.png)

# %% [markdown]
# ### Interpretation
# ![image.png](attachment:a67f0cd3-b69a-48fa-9dcd-ca7cd74c7253.png)![image.png](attachment:7eaab01f-2d20-4ccb-9c13-87ca2b0f37f0.png)

# %% [markdown]
# ### Compared to Local Moran's I
# ![image.png](attachment:b5673c99-a99a-476f-9bd3-86becde1aa34.png)

# %% [markdown]
# ## Getis-Ord Statistics
# ### Definition
# ![image.png](attachment:7797860c-bc46-48d1-af7f-b95852ae5683.png)

# %% [markdown]
# ### Interpretation
# ![image.png](attachment:12a4d22c-34ef-410d-8567-71bd5c84953e.png)
