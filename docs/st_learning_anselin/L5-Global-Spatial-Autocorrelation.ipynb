# %% [markdown]
# # Global Spatial Autocorrelation Measures
# ![image.png](attachment:faf131a0-8f85-4bb1-a71f-0f59290df5ba.png)

# %% [markdown]
# ## Moran's I (1948)
# ![image.png](attachment:e562acb4-ff08-4115-8659-85fc9ee0767e.png)

# %% [markdown]
# ### Inference
# ![image.png](attachment:a90c2d4e-011c-4dad-af4b-e9635f19fab6.png)

# %% [markdown]
# ### Moran-Z-Value
# ![image.png](attachment:8258ca08-3796-430d-804d-317ee3bcba63.png)

# %% [markdown]
# ## Geary's C (1954)
# ![image.png](attachment:59122623-1509-45e3-873d-3397eab48703.png)

# %% [markdown]
# ### Interpretation
# ![image.png](attachment:089de28e-b5c0-4b3c-8c90-d9e16369ded8.png)

# %% [markdown]
# ### Inference
# ![image.png](attachment:32e75e7b-2459-424d-9bec-2c5bc9384e50.png)
