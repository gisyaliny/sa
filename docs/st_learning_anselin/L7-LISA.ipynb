# %% [markdown]
# # Local indicator of Spatial Autocorrelation
# ## LISA Concept (Anselin 1995)
# ![image.png](attachment:5d1b46a8-2c11-4f63-ba07-78abe96cc52e.png)

# %% [markdown]
# ## Local Form of Moran's I (Anselin, 1995)
# ### Definition
# ![image.png](attachment:195d0962-5a32-4b1d-9be2-ac61467a05b2.png)

# %% [markdown]
# ### Inference
# ![image.png](attachment:9d270192-1951-4d9e-b922-9a46e3473f4d.png)

# %% [markdown]
# ### Visualization
# ![image.png](attachment:d852b216-c6f4-4160-a239-74b0f6f924e1.png)
# ![image.png](attachment:5ac513d8-d48f-4b50-a249-976d36808637.png)
# ![image.png](attachment:1661e5ff-9b3f-4b1a-975f-b05d50bdf527.png)

# %% [markdown]
# ![image.png](attachment:5535fae9-43e6-46a5-a6a4-74b04dab2402.png)

# %% [markdown]
# ## LISA Inferential Issues
# ![image.png](attachment:bdc24312-bdcc-4ddd-b258-31e326269d31.png)
#
# ### The Multiple Comparison Problem
# ![image.png](attachment:8e94a86f-1ea4-48dc-904b-fedae85ee2fe.png)

# %% [markdown]
# ![image.png](attachment:80aff14e-cc9d-407f-9f56-2ea0a6d81d80.png)

# %% [markdown]
# ## LISA Limitations
# ![image.png](attachment:1e328a80-d115-4a8d-b0b3-fb27bcdb291f.png)
